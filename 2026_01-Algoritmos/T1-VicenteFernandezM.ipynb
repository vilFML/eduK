# %% [markdown]
# # CC3001 Otoño 2026 Tarea 1
#
# ## Marcador de tenis
# ## Nombre: Vicente Fernández M.
#
# ### Profesores
# Sección 1 Iván Sipirán •
# Sección 2 Patricio Poblete •
# Sección 3 Nelson Baloian
#
# ![marcador-tenis](https://github.com/ppoblete/CC3001-2020-2-Tareas/blob/master/marcador-tenis.png?raw=1)

# %% [markdown]
# El objetivo de esta tarea es que usted implemente un sistema para que el árbitro de un partido de tenis vaya anotando quién gana cada pelota que se juega, y que a partir de esto se lleve actualizado el marcador del juego. Para simplificar, solo se pide llevar el marcador durante un juego, y no para el set ni para el match. También vamos a suponer que los jugadores son "A" y "B", con "A" al servicio. En la cuenta, la primera cifra corresponde a "A" y la segunda a "B".
#
# El marcador en un juego comienza "0-0". Luego, con cada pelota ganada va avanzando a "15", "30", "40", "juego", pero para ganar el juego hay que tener diferencia de dos pelotas ganadas respecto del oponente, de modo que si se llega a "40-40", el siguiente paso es "ventaja" y de ahí a "juego", si se gana la siguiente pelota, o se vuelve a "iguales", si se pierde.
#
# El siguiente programa implementa una versión simplificada de esto, en que gana el que primero llega a 3, lo cual serviría para ir contando sets ganados en un partido "al mejor de 5":

# %%
def marcadorSet(jugadorA, jugadorB):
    print("Juegan", jugadorA, "vs.", jugadorB)                                  # Muestra los nombres en pantalla
    puntosA=0                                                                   # asignados 0 puntos para cada uno en inicio
    puntosB=0
    while True:                                                                 # bucle activo siempre, se inicia con llamar funcion
        print("Marcador: ", puntosA, "-", puntosB)                              # mostrar cant de puntos en inicio del set
        if puntosA==3 or puntosB==3:                                            # Check si alguno llega a 3 ptos despues de cambiar ptaje, termina el match
            break
        x=input("Ingrese A o B: ").upper()                                      # dentro de ciclo principal, se pide ganador
        if x=="A":
            puntosA+=1
        elif x=="B":
            puntosB+=1                                                          # se le suma un pto al que se ingresa como ganador del set
        else:
            print("Error: jugador desconocido:", x)                             # En caso de ingresar nombre desconocido
    if puntosA==3:
        print("Gana", jugadorA)
    else:
        print("Gana", jugadorB)                                                 # fuera de ciclo de juego, mostrar quien gana

# %%
marcadorSet("Federer","Nadal")

# %% [markdown]
# Tomando como base este código, escriba a continuación un programa que implemente lo que se pide, y pruébelo con la siguiente secuencia de entrada. El programa debe terminar cuando un jugador gana el juego.
#
# ```
# A A B A B B B A A B B B
# ```
#
# Además, invente varias otras secuencias y muestre también sus resultados.

# %% [markdown]
# ## ¿Qué hay que entregar?
#
# Usted debe entregar un link a este mismo archivo en colab, modificado de acuerdo a lo que se pide. Haga todos los cambios necesarios para explicar y documentar adecuadamente su código. No olvide poner su nombre.
#
# La tarea es individual. Está prohibido el uso de inteligencia artificial.

# %%
def marcadorJuego(jugadorA, jugadorB):
    print("Comienzo de juego: ", jugadorA, "vs.", jugadorB)                     # Muestra los nombres en pantalla
    puntosA=0                                                                   # asignados 0 puntos para cada uno en inicio
    puntosB=0
    while True:                                                                 # bucle activo siempre, se inicia con llamar funcion
        print("Marcador juego actual: ", puntosA, "-", puntosB)                 # mostrar cant de puntos en inicio del juego
        if puntosA==3 or puntosB==3:                                            # Check si alguno llega a 3 ptos despues de cambiar ptaje en el final, termina juego
            break
        x=input("Ingrese A o B: ").upper()                                      # dentro de ciclo principal, se pide ganador
        if x=="A":
            puntosA+=1
        elif x=="B":
            puntosB+=1                                                          # se le suma un pto al que se ingresa como ganador del set
        else:
            print("Error: jugador desconocido:", x)                             # En caso de ingresar nombre desconocido
    if puntosA==3:
        print("Gana", jugadorA)
    else:
        print("Gana", jugadorB)                                                 # fuera de ciclo de juego, mostrar quien gana

# %%
def marcadorJuego(jugadorA, jugadorB):
    # inician sin puntos
    ptosA = 0
    ptosB = 0
    while (True):
        print("Marcador juego actual: ", ptosA, "-", ptosB)
        # bucle termina cuando alguno llegue a 45 ptos
        if ptosA == 45 or ptosB == 45:
            break

        # En caso de ambos en 40 ptos: Desempate, nuevo bucle while mientras se desempata
        if ptosA == 40 and ptosB == 40:
            # nuevo sistema de ptaje: ventaja, inicio sin ventaja para c/u
            ventajaA = False
            ventajaB = False

            while (True):
                print("Marcador desempate actual. Ventaja A: ", ventajaA, ", Ventaja B: ", ventajaB)


                ganadorExtra = input('Ingrese el ganador del punto: ').upper()

                # Caso si gana A el punto
                if ganadorExtra == 'A':
                    if ventajaA == True:                                        # Tenia ventaja: dar ptos y salir desempate
                        ptosA += 5
                        break
                    elif ventajaA == False and ventajaB == False:               # nadie tiene ventaja, dar ventaja a ganador
                        ventajaA = True
                    elif ventajaB == True:                                      # el otro tiene ventaja: quitarsela
                        ventajaB = False
                
                if ganadorExtra == 'B':                                         # Analogo para B
                    if ventajaB == True:
                        ptosB += 5
                        break
                    elif ventajaA == False and ventajaB == False: 
                        ventajaB = True
                    elif ventajaA == True:
                        ventajaA = False

            # Bloque de codigo en caso de empate esta dentro de bucle principal, debe detenerlo al resolverlo.
            break
        
        ganadorPto = input('Ingrese el ganador del punto A o B: ').upper()
        print('DEBUG: ganador de punto: ', ganadorPto)

        if ganadorPto == 'A':                                                   # Sistema de ptaje incrementa segun ptos actuales
            if ptosA == 0 or 15:
                ptosA += 15
            elif ptosA == 30:
                ptosA += 10
            elif ptosA == 40:
                ptosA += 5
        elif ganadorPto == 'B':
            if ptosB == 0 or 15:
                ptosB += 15
            elif ptosB == 30:
                ptosB += 10
            elif ptosB == 40:
                ptosB += 5
        else:
            print('Error: Jugador desconocido.')

    if ptosA == 45:
        print('Ganador: ', jugadorA)
    elif ptosB == 45:
        print('Ganador: ', jugadorB)

# %%
marcadorJuego('Vixo','Vixa')
# Out:
# Marcador juego actual:  0 - 0
# DEBUG: ganador de punto:  A
# Marcador juego actual:  15 - 0
# DEBUG: ganador de punto:  A
# Marcador juego actual:  30 - 0
# DEBUG: ganador de punto:  B
# Marcador juego actual:  30 - 15
# DEBUG: ganador de punto:  A
# Marcador juego actual:  45 - 15
# Ganador:  Vixo
