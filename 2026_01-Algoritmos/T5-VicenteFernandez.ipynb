# %% [markdown]
# # Nombre: Vicente Fernández M.

# %% [markdown]
# En esta tarea usted debe implementar árboles cartesianos, con las operaciones de insertar y eliminar. Usted debe entregar un link a su tarea en `colab`.
#
# Antes de probar su implementación, ejecute primero las siguientes líneas de código.

# %%
# !pip install aed-utilities

import aed_utilities as aed
# Out:
# Requirement already satisfied: aed-utilities in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (1.0.0)
# Requirement already satisfied: validators in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from aed-utilities) (0.35.0)
# Requirement already satisfied: beautifulsoup4 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from aed-utilities) (4.14.3)
# Requirement already satisfied: graphviz in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from aed-utilities) (0.21)
# Requirement already satisfied: ipykernel in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from aed-utilities) (7.2.0)
# Requirement already satisfied: matplotlib in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from aed-utilities) (3.10.9)
# Requirement already satisfied: ipywidgets in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from aed-utilities) (8.1.8)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from beautifulsoup4->aed-utilities) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from beautifulsoup4->aed-utilities) (4.15.0)
# Requirement already satisfied: comm>=0.1.1 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (9.13.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (1.6.0)
# Requirement already satisfied: packaging>=22 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (26.2)
# Requirement already satisfied: psutil>=5.7 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (6.5.6)
# Requirement already satisfied: traitlets>=5.4.0 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipykernel->aed-utilities) (5.15.0)
# Requirement already satisfied: decorator>=5.1.0 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->aed-utilities) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->aed-utilities) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->aed-utilities) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->aed-utilities) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->aed-utilities) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->aed-utilities) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->aed-utilities) (0.6.3)
# Requirement already satisfied: wcwidth in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->aed-utilities) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->aed-utilities) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from jupyter-client>=8.8.0->ipykernel->aed-utilities) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->aed-utilities) (4.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel->aed-utilities) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel->aed-utilities) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->aed-utilities) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->aed-utilities) (3.0.1)
# Requirement already satisfied: pure-eval in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->aed-utilities) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipywidgets->aed-utilities) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from ipywidgets->aed-utilities) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from matplotlib->aed-utilities) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from matplotlib->aed-utilities) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from matplotlib->aed-utilities) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from matplotlib->aed-utilities) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from matplotlib->aed-utilities) (2.4.6)
# Requirement already satisfied: pillow>=8 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from matplotlib->aed-utilities) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/vila/dev/envs/venv-MSI/lib/python3.14/site-packages (from matplotlib->aed-utilities) (3.3.2)

# %% [markdown]
# ---
# # Descripción de un árbol cartesiano

# %% [markdown]
# Un *árbol cartesiano* es un árbol binario en que cada nodo interno contiene un par ordenado $(x,y)$, tal que:
#
# * Si se consideran las coordenadas $x$, el árbol es un ABB
# * Si se consideran las coordenadas $y$, el árbol es un árbol de prioridad
#
# La siguiente figura muestra a un árbol cartesiano en que la máxima prioridad corresponde al valor mínimo de $y$:
#
# ![cartesian-tree](https://github.com/ivansipiran/AED-Apuntes/blob/main/recursos/cartesian-tree.png?raw=1)
#
# Intuitivamente, podemos imaginar que la prioridad $y$ corresponde a la hora en que la llave $x$ ingresó al árbol. Esto explica que la raíz tenga el valor mínimo de $y$, y que estos valores vayan creciendo a medida que descendemos en el árbol.
#
# Sin embargo, _no estamos obligados a insertar las llaves en orden cronológico_. En efecto, veremos que un nuevo par $(x,y)$ se puede insertar en cualquier momento, aunque su $y$ no sea mayor que los de los nodos que ya están en el árbol.
#
# Para insertar un nuevo par ordenado en un árbol cartesiano, primero efectuamos una inserción como si fuera un ABB, con lo cual el nuevo nodo cumple con las restricciones "izquierda-derecha" en su coordenada $x$, pero posiblemente no con las restricciones de prioridad "arriba-abajo" de la coordenada $y$. Para corregir esto último, a continuación, hacemos una serie de rotaciones para que el nuevo nodo vaya "trepando" hasta que cumpla con las restricciones de prioridad.
#
# También es posible eliminar un nodo dado de un árbol cartesiano. Para esto, una vez ubicado el nodo que contiene el $x$ que se va a eliminar, podemos imaginar que le cambiamos la prioridad a una prioridad pésima ("$+\infty$") y luego lo "hundimos" haciendo una serie de rotaciones, rotando siempre con el hijo de mejor prioridad (=valor de $y$ menor), hasta llegar al fondo. Una vez ahí, es trivial eliminarlo, porque no tiene hijos.

# %% [markdown]
# # La Tarea
#
#
#
# En primer lugar, usted debe implementar las funciones `insert` y `delete` en la clase `Nodoi` y `Nodoe`. Puede crear todas las funciones auxiliares que requiera para implementar estos métodos. No está permitido usar ninguna función ya programada en módulos de Python. En caso de requerirla, puede utilizar la función predefinida `isinstance` de Python. Note que mientras usted no agregue su implementación de `insert` y `delete` en ambos tipos de nodos, el código no compilará correctamente.

# %%
import aed_utilities as aed

class Nodoi:
    def __init__(self, izq, info, der):
        self.izq=izq
        self.info=info # el campo info contiene una tupla (x,y)
        self.der=der
    def right_rotation(self):
        return(Nodoi(self.izq.izq,
                     self.izq.info,
                     Nodoi(self.izq.der,self.info,self.der)))
    def left_rotation(self):
        return(Nodoi(Nodoi(self.izq,self.info,self.der.izq),
                     self.der.info,
                     self.der.der))

    def search(self,x):
        if x==self.info:
            return self
        if x<self.info:
            return self.izq.search(x)
        else:
            return self.der.search(x)

    def insert(self,xy): # insertar la tupla xy=(x,y) donde x es la llave e y es la prioridad
        # insercion en abb
        key = xy[0]
        prio = xy[1]

        assert key!=self.info[0]                                                # no esta llave

        # se reemplaza nodo con x según sea menor (izq) o mayor (der)
        if key<self.info[0]:
            self.izq = self.izq.insert(xy)

            #si hay que corregir prio:
            if (self.izq.info[1] < self.info[1]):
                #rotar hacia derecha pues se inserto en nodo izq
                return self.right_rotation()

        else: #key >= self.info[0]
            self.der = self.der.insert(xy)

            if (self.der.info[1] < self.info[1]):                               #revisar correcion de prio
                return self.left_rotation()

        return self



    def delete(self,x): # eliminar el nodo con llave x
        #primero se busca llave
        if (x < self.info[0]):
            return Nodoi(self.izq.delete(x), self.info, self.der)               
        elif (x > self.info[0]):
            return Nodoi(self.izq, self.info, self.der.delete(x))

        else:   #se esta en nodo a eliminar
            # si no tiene hijos: retornar nodo externo
            if (isinstance(self.izq, Nodoe) and isinstance(self.der, Nodoe)):
                return Nodoe()                
            
            else:   #si tiene hijos, rotar segun caso
                if isinstance(self.izq, Nodoe):
                    rotado = self.left_rotation()                               # bajar self, subir hijo
                    rotado.izq = rotado.izq.delete(x)                           # orden cambiado: llamar eliminacion recursivamente
                    return rotado
                elif isinstance(self.der, Nodoe):
                    rotado = self.right_rotation()
                    rotado.der = rotado.der.delete(x)
                    return rotado

                elif isinstance(self.izq, Nodoi) and isinstance(self.der, Nodoi):
                    #comparar prioridad entre los dos hijos y rotar
                    if self.izq.info[1] < self.der.info[1]:                     # izq prioritario
                        rotado = self.right_rotation()                          # bajar self, subir hijo
                        rotado.der = rotado.der.delete(x)                       # orden cambiado, llamar eliminar recursivo
                        return rotado

                    else:
                        rotado = self.left_rotation()
                        rotado.izq = rotado.izq.delete(x)
                        return rotado
                        
            return self
                    

class Nodoe:
    def __init__(self):
        pass

    def search(self,x):
        return None

    def insert(self,xy): # insertar la tupla xy=(x,y) donde x es la llave e y es la prioridad
        #insercion en abb
        return Nodoi(Nodoe(), xy, Nodoe())

    def delete(self,x): # eliminar el nodo con llave x
        pass


class ArbolCartesiano:
    def __init__(self,raiz=Nodoe()):
        self.raiz=raiz
    def search(self,x):
        return self.raiz.search(x)
    def insert(self,xy):
        self.raiz=self.raiz.insert(xy)
    def delete(self,x):
        self.raiz=self.raiz.delete(x)

    def dibujar(self):
      btd = aed.BinaryTreeDrawer(fieldData="info", fieldLeft="izq", fieldRight="der", classNone=Nodoe, drawNull=True, shapeInternal='oval')
      btd.draw_tree(self, "raiz")

# %% [markdown]
# Luego, pruebe su implementación con las siguientes operaciones (verifique con el dibujo de árbol que la operación se realizó correctamente)):

# %%
a=ArbolCartesiano()
a.dibujar()

# %%
a.insert((82,0.30))
a.dibujar()

# %%
a.insert((15,0.61))
a.dibujar()

# %%
a.insert((64,0.12))
a.dibujar()

# %%
a.insert((35,0.84))
a.dibujar()

# %%
a.delete(64)
a.dibujar()

# %% [markdown]
# Por último, pruebe su código con el siguiente programa:

# %%
a = ArbolCartesiano()
a.insert((1,50))
a.insert((2,10))
a.insert((3,40))
a.insert((4,20))
a.insert((5,90))
a.insert((6,80))
a.insert((7,30))
a.insert((8,70))
a.insert((9,60))
a.insert((10,0))

a.dibujar()

assert a.raiz.info == (10, 0)
assert a.raiz.izq.info == (2, 10) and isinstance(a.raiz.der, Nodoe)
assert a.raiz.izq.izq.info == (1, 50) and a.raiz.izq.der.info == (4, 20)
assert isinstance(a.raiz.izq.izq.izq, Nodoe) and  isinstance(a.raiz.izq.izq.der, Nodoe) and a.raiz.izq.der.izq.info == (3, 40) and a.raiz.izq.der.der.info == (7, 30)
assert isinstance(a.raiz.izq.der.izq.izq, Nodoe) and isinstance(a.raiz.izq.der.izq.der, Nodoe) and a.raiz.izq.der.der.izq.info == (6, 80) and a.raiz.izq.der.der.der.info == (9, 60)
assert a.raiz.izq.der.der.izq.izq.info == (5, 90) and isinstance(a.raiz.izq.der.der.izq.der, Nodoe) and a.raiz.izq.der.der.der.izq.info == (8, 70) and isinstance(a.raiz.izq.der.der.der.der, Nodoe)
assert isinstance(a.raiz.izq.der.der.izq.izq.izq, Nodoe) and isinstance(a.raiz.izq.der.der.izq.izq.der, Nodoe) and isinstance(a.raiz.izq.der.der.der.izq.izq, Nodoe) and isinstance(a.raiz.izq.der.der.der.izq.der, Nodoe)

a.delete(2)
a.delete(6)
a.delete(10)
a.delete(8)
a.delete(4)

a.dibujar()

assert a.raiz.info == (7, 30)
assert a.raiz.izq.info == (3, 40) and a.raiz.der.info == (9, 60)
assert a.raiz.izq.izq.info == (1, 50) and a.raiz.izq.der.info == (5, 90) and isinstance(a.raiz.der.izq, Nodoe) and isinstance(a.raiz.der.der, Nodoe)
assert isinstance(a.raiz.izq.izq.izq, Nodoe) and isinstance(a.raiz.izq.izq.der, Nodoe) and isinstance(a.raiz.izq.der.izq, Nodoe) and isinstance(a.raiz.izq.der.der, Nodoe)

print("Su código pasó todos los tests, ¡felicitaciones!")
# Out:
# Su código pasó todos los tests, ¡felicitaciones!
